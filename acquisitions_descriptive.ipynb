# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from nltk.corpus import stopwords
import matplotlib.pylab as pylab
import matplotlib.pyplot as plt
from pandas import get_dummies
import matplotlib as mpl
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib
import warnings
import sklearn
import string
import scipy
import numpy
import nltk
import json
import sys
import csv
import os

# %%
#import dataset
acquisitions = pd.read_csv("/Users/lucyhyde/Desktop/Practicum_Data/acquisitions.csv")

# %%
type(acquisitions)
# Out:
# pandas.core.frame.DataFrame

# %%
#shape
print(acquisitions.shape)
# Out:
# (22206, 6)

# %%
print(acquisitions.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22206 entries, 0 to 22205
# Data columns (total 6 columns):
# org_permalink         22205 non-null object
# acq_announced_on      22206 non-null object
# acq_price_usd         3839 non-null float64
# acq_type              19152 non-null object
# acq_status            18788 non-null object
# acquirer_permalink    22206 non-null object
# dtypes: float64(1), object(5)
# memory usage: 1.0+ MB
# None

# %%
acquisitions.head(10)
# Out:
#             org_permalink acq_announced_on  acq_price_usd     acq_type  \
# 0  0-in-design-automation       2004-09-01            NaN  acquisition
# 1            1000-markets       2012-09-22            NaN          NaN
# 2         1000museums-com       2016-07-26            NaN  acquisition
# 3      1011-web-solutions       2014-01-30            NaN  acquisition
# 4                101-wkqx       2018-04-03            NaN  acquisition
# 5                  10best       2011-01-25            NaN  acquisition
# 6            10-day-media       2018-10-26            NaN  acquisition
# 7                  10east       2009-04-14            NaN          NaN
# 8            10-foot-wave       2018-03-28            NaN        merge
# 9              10k-wizard       2008-12-04            NaN          NaN
#
#   acq_status      acquirer_permalink
# 0        NaN         mentor-graphics
# 1        NaN                bonanzle
# 2   complete           art-authority
# ...

# %%
acquisitions.tail(10)
# Out:
#                 org_permalink acq_announced_on  acq_price_usd     acq_type  \
# 22196      zxy-sport-tracking       2014-04-06      5001780.0  acquisition
# 22197                  zycron       2017-04-06     20000000.0  acquisition
# 22198  zylera-pharmaceuticals       2017-11-17            NaN  acquisition
# 22199             zyman-group       2005-04-01            NaN  acquisition
# 22200                 zymetis       2011-07-06            NaN  acquisition
# 22201             zync-render       2014-08-26            NaN  acquisition
# 22202      zyray-wireless-inc       2004-06-16     96000000.0  acquisition
# 22203                  zyrion       2013-06-25            NaN          NaN
# 22204                  zystor       2010-08-18    115000000.0  acquisition
# 22205                     NaN       2012-01-25            NaN          lbo
#
#       acq_status       acquirer_permalink
# 22196   complete               chyronhego
# 22197   complete              bg-staffing
# ...

# %%
acquisitions.describe()
# Out:
#        acq_price_usd
# count   3.839000e+03
# mean    4.646451e+08
# std     1.839873e+09
# min     0.000000e+00
# 25%     2.100000e+07
# 50%     7.932095e+07
# 75%     2.900000e+08
# max     5.450000e+10

# %%
acquisitions.columns
# Out:
# Index(['org_permalink', 'acq_announced_on', 'acq_price_usd', 'acq_type',
#        'acq_status', 'acquirer_permalink'],
#       dtype='object')

# %%
acquisitions.nlargest(10, 'acq_price_usd')
# Out:
#                    org_permalink acq_announced_on  acq_price_usd     acq_type  \
# 16520           reynolds-america       2017-01-17   5.450000e+10  acquisition
# 36              21st-century-fox       2017-12-14   5.240000e+10  acquisition
# 18149             spectra-energy       2016-09-06   2.800000e+10          lbo
# 1137    american-general-company       2001-08-30   2.300000e+10  acquisition
# 6597      energy-transfer-equity       2016-11-21   2.100000e+10  acquisition
# 14826              pharmacyclics       2015-03-04   2.100000e+10  acquisition
# 21485  wellpoint-health-networks       2003-10-27   2.088000e+10  acquisition
# 21541                   whatsapp       2014-02-19   1.900000e+10  acquisition
# 10372                     jarden       2015-12-14   1.540000e+10  acquisition
# 9107                     hospira       2015-02-05   1.500000e+10  acquisition
#
#       acq_status            acquirer_permalink
# 16520   complete      british-american-tobacco
# ...

# %%
acquisitions.isnull().sum()
# Out:
# org_permalink             1
# acq_announced_on          0
# acq_price_usd         18367
# acq_type               3054
# acq_status             3418
# acquirer_permalink        0
# dtype: int64
